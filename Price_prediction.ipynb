# %%
import pandas as pd
from lib.residental_data_source import ResidentialDataSource

# %%
data_source = ResidentialDataSource()
data_set = data_source.fetch_data_set()
data_set.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 index()           Регион Населенный пункт  \
# 0             0           0       1  Приморский край         Арсеньев
# 1             1           1       2  Приморский край         Арсеньев
# 2             2           2       3  Приморский край         Арсеньев
# 3             3           3       4  Приморский край         Арсеньев
# 4             4           4       5  Приморский край         Арсеньев
#
#     Группа компаний  ID проекта    Проект  Корпус Класс недвижимости  ...  \
# 0  Восточные ворота      206831  Северный   19729            Комфорт  ...
# 1  Восточные ворота      206831  Северный   19729            Комфорт  ...
# 2  Восточные ворота      206831  Северный   19729            Комфорт  ...
# 3  Восточные ворота      206831  Северный   19729            Комфорт  ...
# 4  Восточные ворота      206831  Северный   19729            Комфорт  ...
#
#   Внутренний двор без машин Вид из окна на море  Дата сбора информации  \
# 0                       NaN                 NaN                    NaN
# 1                       NaN                 NaN                    NaN
# 2                       NaN                 NaN                    NaN
# 3                       NaN                 NaN                    NaN
# 4                       NaN                 NaN                    NaN
#
#    Общая сумма полученных денег с проданных квартир, руб  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Количество проданных машиномест  Количество проданных квартир  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
#
#   Общая площадь проданных квартир  Процент распроданности  \
# 0                             NaN                     NaN
# 1                             NaN                     NaN
# 2                             NaN                     NaN
# 3                             NaN                     NaN
# 4                             NaN                     NaN
#
#    Кумулятивная средняя стоимость кв.метра  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Количество проданных нежилых помещений
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
# [5 rows x 124 columns]
